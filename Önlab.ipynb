# %% [markdown]
# <a href="https://colab.research.google.com/github/Egoago/EyeTracker/blob/main/%C3%96nlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2D regression

# %% [markdown]
# ##Preparing the data

# %% [markdown]
# ###Defining the control points

# %%
import numpy as np
from matplotlib import pyplot as plt

np.random.seed(0)
pointNum = 5
points = np.random.random((pointNum,2))
plt.scatter(points[:,0], points[:,1])
points
# Out:
# array([[0.5488135 , 0.71518937],
#        [0.60276338, 0.54488318],
#        [0.4236548 , 0.64589411],
#        [0.43758721, 0.891773  ],
#        [0.96366276, 0.38344152]])

# %%
import math

def dist(p, points):
  return np.linalg.norm(points-p, axis = 1).min()

print(dist([0.5,0.5], points))
# Out:
# 0.11213746732281339

# %% [markdown]
# ###Generating training data

# %%
from matplotlib import cm

xNum = 30000
X = np.random.random((xNum,2))
Y = np.empty(xNum)
for i,x in enumerate(X):
  Y[i] = dist(x, points)

plt.scatter(X[:,0], X[:,1], c=Y, s = 10, cmap = cm.seismic)
plt.colorbar()

# %% [markdown]
# ##Creating model
